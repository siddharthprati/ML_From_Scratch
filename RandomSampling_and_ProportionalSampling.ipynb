# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm 
import pylab as py 
import pandas as pd
from sklearn.datasets import load_boston
import random as r

# %%
b = pd.DataFrame(load_boston().data)
b.columns = load_boston().feature_names
print(b.head(8))
print(b.shape)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# 5  0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622  3.0  222.0
# 6  0.08829  12.5   7.87   0.0  0.524  6.012  66.6  5.5605  5.0  311.0
# 7  0.14455  12.5   7.87   0.0  0.524  6.172  96.1  5.9505  5.0  311.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33
# 5     18.7  394.12   5.21
# 6     15.2  395.60  12.43
# 7     15.2  396.90  19.15
# (506, 13)

# %%
#random_sampling_of_boston_dataset

random_sample = b.sample(frac=0.2,replace=False,random_state=0)
random_sample
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 329   0.06724   0.0   3.24   0.0  0.460  6.333   17.2  5.2146   4.0  430.0
# 371   9.23230   0.0  18.10   0.0  0.631  6.216  100.0  1.1691  24.0  666.0
# 219   0.11425   0.0  13.89   1.0  0.550  6.373   92.4  3.3633   5.0  276.0
# 403  24.80170   0.0  18.10   0.0  0.693  5.349   96.0  1.7028  24.0  666.0
# 78    0.05646   0.0  12.83   0.0  0.437  6.232   53.7  5.0141   5.0  398.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...   ...    ...
# 374  18.49820   0.0  18.10   0.0  0.668  4.138  100.0  1.1370  24.0  666.0
# 56    0.02055  85.0   0.74   0.0  0.410  6.383   35.7  9.1876   2.0  313.0
# 455   4.75237   0.0  18.10   0.0  0.713  6.525   86.5  2.4358  24.0  666.0
# 60    0.14932  25.0   5.13   0.0  0.453  5.741   66.2  7.2254   8.0  284.0
# 213   0.14052   0.0  10.59   0.0  0.489  6.375   32.3  3.9454   4.0  277.0
#
#      PTRATIO       B  LSTAT
# 329     16.9  375.21   7.34
# ...

# %%
#proportional sampling
weight = [0.05,0.05,0.1,0.15,.02,0.03,.5,0.07,0.03]
for i in range(1,498):
    weight.append(0)

prop_sample = b.sample(frac=0.02,replace=True,weights= weight)
prop_sample
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# 6  0.08829  12.5   7.87   0.0  0.524  6.012  66.6  5.5605  5.0  311.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 6  0.08829  12.5   7.87   0.0  0.524  6.012  66.6  5.5605  5.0  311.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 6  0.08829  12.5   7.87   0.0  0.524  6.012  66.6  5.5605  5.0  311.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 7  0.14455  12.5   7.87   0.0  0.524  6.172  96.1  5.9505  5.0  311.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 4     18.7  396.90   5.33
# 6     15.2  395.60  12.43
# 3     18.7  394.63   2.94
# 6     15.2  395.60  12.43
# 1     17.8  396.90   9.14
# ...
